# %% [markdown]
# # Classification Task for target compound

# %%
import torch
import torchdrug as td
from torchdrug import data
import pandas as pd
# %matplotlib inline


DATASET_TYPE = "single" #"single"
DATASET_NAME = "chembl29_predicting_target_P14416_P42336"
CSV_DATA_PATH = "../data/"+ DATASET_NAME + ".csv"

smiles_df = pd.read_csv(CSV_DATA_PATH, sep = ",")

# %% [markdown]
# run the next cell if you need to create csv

# %%
# DATA_PATH =  "../data/"+ DATASET_NAME + ".tsv"

# smiles_df = pd.read_csv(DATA_PATH, sep = "\t")
# display(smiles_df.head())

# smiles_df["label"] = pd.factorize(smiles_df["label"])[0]

# if DATASET_TYPE == "dual":

#     smiles_df["target1"] = 0
#     smiles_df["target2"] = 0

#     smiles_df.loc[smiles_df.label == 0, 'target1'] = 1
#     smiles_df.loc[smiles_df.label == 0, 'target2'] = 1

#     smiles_df.loc[smiles_df.label == 1, 'target1'] = 1
#     smiles_df.loc[smiles_df.label == 2, 'target2'] = 1

# smiles_df.to_csv(CSV_DATA_PATH, index = False)

# %%
display(smiles_df.head())
# Out:
#                          nonstereo_aromatic_smiles    target_pair  label  \
# 0      C#CCn1c(=O)c2c(nc3n2CCCN3Cc2ccccc2)n(C)c1=O  P27338_P29274      0
# 1    C#CCn1c(=O)c2c(nc3n2CCCN3Cc2ccccc2OC)n(C)c1=O  P27338_P29274      0
# 2  CC(=O)c1ccc(C=Cc2cc3c(c(=O)n(C)c(=O)n3C)n2C)cc1  P27338_P29274      0
# 3          CC1Oc2ccc(Nc3ncnc4c3oc3ccccc34)cc2NC1=O  P27338_P29274      0
# 4    CCCOc1ccc(C=Cc2cc3c(c(=O)n(C)c(=O)n3C)n2C)cc1  P27338_P29274      0
#
#    target1  target2
# 0        1        1
# 1        1        1
# 2        1        1
# 3        1        1
# 4        1        1

# %%
# ! powershell -command "Set-ExecutionPolicy -ExecutionPolicy AllSigned -Scope CurrentUser"
# ! powershell -command "Import-VisualStudioVars -Architecture x64"
# ! powershell -command "$env:LIB += \";C:\Users\Mastro\anaconda3\envs\graphshap_cheminfo\libs\" "

# %% [markdown]
# Molecules

# %%
smile = smiles_df.iloc[7]["nonstereo_aromatic_smiles"]
mol = data.Molecule.from_smiles(smile)
mol.visualize()
print(mol.node_feature.shape)
print(mol.edge_feature.shape)
# Out:
# torch.Size([24, 69])
# torch.Size([52, 19])
# C:\Users\Mastro\anaconda3\envs\graphshap_cheminfo\lib\site-packages\torchdrug\data\molecule.py:468: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Graph Operations

# %%
smiles_list = smiles_df.iloc[0:4]["nonstereo_aromatic_smiles"].values
mols = data.PackedMolecule.from_smiles(smiles_list)
mols.visualize()
mols = mols.cuda()
print(mols)
# Out:
# C:\Users\Mastro\anaconda3\envs\graphshap_cheminfo\lib\site-packages\torchdrug\data\molecule.py:858: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# PackedMolecule(batch_size=4, num_nodes=[26, 28, 25, 26], num_edges=[58, 62, 54, 60], num_relation=4, device='cuda:0')

# %%
node_in, node_out, bond_type = mols.edge_list.t()
edge_mask = (mols.atom_type[node_in] == td.CARBON) | \
            (mols.atom_type[node_out] == td.CARBON)
mols = mols.edge_mask(edge_mask)
mols.visualize()

# %% [markdown]
# ## Create Custom MoleculeDataset

# %%
import os

from torchdrug import data, utils
from torchdrug.core import Registry as R
from torchdrug.utils import doc


@R.register("datasets.ChEMBL") #only first time you launch the class
#@doc.copy_args(data.MoleculeDataset.load_csv, ignore=("path", "smiles_field", "target_fields"))
class ChEMBL(data.MoleculeDataset):
    

    def __init__(self, path, smiles_field, target_fields, verbose=1, **kwargs):
        # path = os.path.expanduser(path)# if not os.path.exists(path):
        #     os.makedirs(path)
        self.path = path
        self.smiles_field = smiles_field
        self.target_fields= target_fields
        #print(self.path)
        # zip_file = utils.download(self.url, path, md5=self.md5)
        # csv_file = utils.extract(zip_file)

        self.load_csv(self.path, smiles_field=self.smiles_field, target_fields=self.target_fields,
                      verbose=verbose, **kwargs)

# %%
target_fields = ["target1", "target2"] if DATASET_TYPE == "dual" else ["label"]

chembl_dataset = ChEMBL(path = CSV_DATA_PATH, smiles_field = "nonstereo_aromatic_smiles", target_fields = target_fields)
chembl_dataset
# Out:
# Loading ../data/chembl29_dt_cpds_P27338_P29274.csv: 100%|██████████| 5701/5701 [00:00<00:00, 44300.34it/s]
# Constructing molecules from SMILES: 100%|██████████| 5700/5700 [00:20<00:00, 280.10it/s]
# ChEMBL(
#   #sample: 5700
#   #task: 2
# )

# %%
chembl_dataset.tasks
# Out:
# ['target1', 'target2']

# %% [markdown]
# ## Define Molecule Classifier

# %% [markdown]
# ### Load and Prepare Dataset Splits

# %%
from torchdrug import datasets

lengths = [int(0.8 * len(chembl_dataset)), int(0.1 * len(chembl_dataset))]
lengths += [len(chembl_dataset) - sum(lengths)]
train_set, valid_set, test_set = torch.utils.data.random_split(chembl_dataset, lengths)

# %% [markdown]
# ### Define a Graph Neural Network for Classification
# We use a GIN (Graph Isomorphism Network)

# %%
from torchdrug import core, models, tasks

model = models.GIN(input_dim=chembl_dataset.node_feature_dim,
                   hidden_dims=[256, 256, 256, 256],
                   short_cut=True, batch_norm=True, concat_hidden=True)

# %%
task = tasks.PropertyPrediction(model, task=chembl_dataset.tasks,
                                criterion="bce", metric=("auprc", "auroc"))

# %% [markdown]
# ### Train the Model
# Launch twice if it reports compliling errors :-)

# %%
optimizer = torch.optim.Adam(task.parameters(), lr=1e-3)
solver = core.Engine(task, train_set, valid_set, test_set, optimizer,
                     batch_size=1024, gpus=[0])
solver.train(num_epoch=100)
# Out:
# 17:13:37   Preprocess training set
# 17:13:37   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:37   Epoch 0 begin
# 17:13:38   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:38   binary cross entropy: 7.3006
# 17:13:39   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:39   Epoch 0 end
# 17:13:39   duration: 1.78 secs
# 17:13:39   speed: 2.81 batch / sec
# 17:13:39   ETA: 2.94 mins
# 17:13:39   max GPU memory: 738.8 MiB
# 17:13:39   ------------------------------
# 17:13:39   average binary cross entropy: 4.24627
# 17:13:39   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:39   Epoch 1 begin
# 17:13:40   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:40   Epoch 1 end
# 17:13:40   duration: 1.00 secs
# 17:13:40   speed: 5.02 batch / sec
# 17:13:40   ETA: 2.27 mins
# 17:13:40   max GPU memory: 746.9 MiB
# 17:13:40   ------------------------------
# 17:13:40   average binary cross entropy: 1.96796
# 17:13:40   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:40   Epoch 2 begin
# 17:13:41   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:41   Epoch 2 end
# 17:13:41   duration: 0.98 secs
# 17:13:41   speed: 5.12 batch / sec
# 17:13:41   ETA: 2.02 mins
# 17:13:41   max GPU memory: 738.9 MiB
# 17:13:41   ------------------------------
# 17:13:41   average binary cross entropy: 0.916105
# 17:13:41   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:41   Epoch 3 begin
# 17:13:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:42   Epoch 3 end
# 17:13:42   duration: 0.99 secs
# 17:13:42   speed: 5.04 batch / sec
# 17:13:42   ETA: 1.90 mins
# 17:13:42   max GPU memory: 741.0 MiB
# 17:13:42   ------------------------------
# 17:13:42   average binary cross entropy: 0.623853
# 17:13:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:42   Epoch 4 begin
# 17:13:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:42   Epoch 4 end
# 17:13:42   duration: 0.95 secs
# 17:13:42   speed: 5.25 batch / sec
# 17:13:42   ETA: 1.80 mins
# 17:13:42   max GPU memory: 743.0 MiB
# 17:13:42   ------------------------------
# 17:13:42   average binary cross entropy: 0.446227
# 17:13:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:42   Epoch 5 begin
# 17:13:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:43   Epoch 5 end
# 17:13:43   duration: 0.98 secs
# 17:13:43   speed: 5.12 batch / sec
# 17:13:43   ETA: 1.74 mins
# 17:13:43   max GPU memory: 742.1 MiB
# 17:13:43   ------------------------------
# 17:13:43   average binary cross entropy: 0.281561
# 17:13:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:43   Epoch 6 begin
# 17:13:44   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:44   Epoch 6 end
# 17:13:44   duration: 0.99 secs
# 17:13:44   speed: 5.05 batch / sec
# 17:13:44   ETA: 1.70 mins
# 17:13:44   max GPU memory: 741.5 MiB
# 17:13:44   ------------------------------
# 17:13:44   average binary cross entropy: 0.233858
# 17:13:44   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:44   Epoch 7 begin
# 17:13:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:45   Epoch 7 end
# 17:13:45   duration: 0.97 secs
# 17:13:45   speed: 5.16 batch / sec
# 17:13:45   ETA: 1.65 mins
# 17:13:45   max GPU memory: 739.1 MiB
# 17:13:45   ------------------------------
# 17:13:45   average binary cross entropy: 0.182792
# 17:13:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:45   Epoch 8 begin
# 17:13:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:46   Epoch 8 end
# 17:13:46   duration: 1.00 secs
# 17:13:46   speed: 5.00 batch / sec
# 17:13:46   ETA: 1.62 mins
# 17:13:46   max GPU memory: 738.9 MiB
# 17:13:46   ------------------------------
# 17:13:46   average binary cross entropy: 0.178698
# 17:13:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:46   Epoch 9 begin
# 17:13:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:47   Epoch 9 end
# 17:13:47   duration: 0.94 secs
# 17:13:47   speed: 5.33 batch / sec
# 17:13:47   ETA: 1.59 mins
# 17:13:47   max GPU memory: 738.8 MiB
# 17:13:47   ------------------------------
# 17:13:47   average binary cross entropy: 0.167189
# 17:13:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:47   Epoch 10 begin
# 17:13:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:48   Epoch 10 end
# 17:13:48   duration: 0.95 secs
# 17:13:48   speed: 5.26 batch / sec
# 17:13:48   ETA: 1.55 mins
# 17:13:48   max GPU memory: 741.0 MiB
# 17:13:48   ------------------------------
# 17:13:48   average binary cross entropy: 0.148337
# 17:13:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:48   Epoch 11 begin
# 17:13:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:49   Epoch 11 end
# 17:13:49   duration: 0.97 secs
# 17:13:49   speed: 5.17 batch / sec
# 17:13:49   ETA: 1.53 mins
# 17:13:49   max GPU memory: 744.1 MiB
# 17:13:49   ------------------------------
# 17:13:49   average binary cross entropy: 0.134878
# 17:13:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:49   Epoch 12 begin
# 17:13:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:50   Epoch 12 end
# 17:13:50   duration: 0.99 secs
# 17:13:50   speed: 5.05 batch / sec
# 17:13:50   ETA: 1.50 mins
# 17:13:50   max GPU memory: 744.1 MiB
# 17:13:50   ------------------------------
# 17:13:50   average binary cross entropy: 0.127684
# 17:13:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:50   Epoch 13 begin
# 17:13:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:51   Epoch 13 end
# 17:13:51   duration: 0.96 secs
# 17:13:51   speed: 5.21 batch / sec
# 17:13:51   ETA: 1.48 mins
# 17:13:51   max GPU memory: 744.5 MiB
# 17:13:51   ------------------------------
# 17:13:51   average binary cross entropy: 0.137838
# 17:13:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:51   Epoch 14 begin
# 17:13:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:52   Epoch 14 end
# 17:13:52   duration: 0.95 secs
# 17:13:52   speed: 5.27 batch / sec
# 17:13:52   ETA: 1.45 mins
# 17:13:52   max GPU memory: 740.3 MiB
# 17:13:52   ------------------------------
# 17:13:52   average binary cross entropy: 0.140746
# 17:13:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:52   Epoch 15 begin
# 17:13:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:53   Epoch 15 end
# 17:13:53   duration: 0.96 secs
# 17:13:53   speed: 5.20 batch / sec
# 17:13:53   ETA: 1.43 mins
# 17:13:53   max GPU memory: 741.9 MiB
# 17:13:53   ------------------------------
# 17:13:53   average binary cross entropy: 0.123327
# 17:13:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:53   Epoch 16 begin
# 17:13:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:54   Epoch 16 end
# 17:13:54   duration: 0.95 secs
# 17:13:54   speed: 5.27 batch / sec
# 17:13:54   ETA: 1.41 mins
# 17:13:54   max GPU memory: 747.0 MiB
# 17:13:54   ------------------------------
# 17:13:54   average binary cross entropy: 0.134654
# 17:13:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:54   Epoch 17 begin
# 17:13:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:55   Epoch 17 end
# 17:13:55   duration: 0.94 secs
# 17:13:55   speed: 5.34 batch / sec
# 17:13:55   ETA: 1.38 mins
# 17:13:55   max GPU memory: 742.0 MiB
# 17:13:55   ------------------------------
# 17:13:55   average binary cross entropy: 0.163792
# 17:13:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:55   Epoch 18 begin
# 17:13:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:56   Epoch 18 end
# 17:13:56   duration: 0.96 secs
# 17:13:56   speed: 5.20 batch / sec
# 17:13:56   ETA: 1.36 mins
# 17:13:56   max GPU memory: 743.1 MiB
# 17:13:56   ------------------------------
# 17:13:56   average binary cross entropy: 0.143876
# 17:13:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:56   Epoch 19 begin
# 17:13:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:57   Epoch 19 end
# 17:13:57   duration: 1.06 secs
# 17:13:57   speed: 4.72 batch / sec
# 17:13:57   ETA: 1.35 mins
# 17:13:57   max GPU memory: 743.3 MiB
# 17:13:57   ------------------------------
# 17:13:57   average binary cross entropy: 0.123974
# 17:13:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:57   Epoch 20 begin
# 17:13:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:57   binary cross entropy: 0.111434
# 17:13:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:58   Epoch 20 end
# 17:13:58   duration: 1.14 secs
# 17:13:58   speed: 4.40 batch / sec
# 17:13:58   ETA: 1.34 mins
# 17:13:58   max GPU memory: 747.3 MiB
# 17:13:58   ------------------------------
# 17:13:58   average binary cross entropy: 0.107462
# 17:13:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:58   Epoch 21 begin
# 17:13:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:59   Epoch 21 end
# 17:13:59   duration: 1.02 secs
# 17:13:59   speed: 4.89 batch / sec
# 17:13:59   ETA: 1.32 mins
# 17:13:59   max GPU memory: 743.8 MiB
# 17:13:59   ------------------------------
# 17:13:59   average binary cross entropy: 0.0943332
# 17:13:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:13:59   Epoch 22 begin
# 17:14:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:00   Epoch 22 end
# 17:14:00   duration: 1.04 secs
# 17:14:00   speed: 4.79 batch / sec
# 17:14:00   ETA: 1.31 mins
# 17:14:00   max GPU memory: 741.7 MiB
# 17:14:00   ------------------------------
# 17:14:00   average binary cross entropy: 0.0869966
# 17:14:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:00   Epoch 23 begin
# 17:14:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:01   Epoch 23 end
# 17:14:01   duration: 1.04 secs
# 17:14:01   speed: 4.79 batch / sec
# 17:14:01   ETA: 1.29 mins
# 17:14:01   max GPU memory: 743.6 MiB
# 17:14:01   ------------------------------
# 17:14:01   average binary cross entropy: 0.079353
# 17:14:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:01   Epoch 24 begin
# 17:14:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:02   Epoch 24 end
# 17:14:02   duration: 0.98 secs
# 17:14:02   speed: 5.12 batch / sec
# 17:14:02   ETA: 1.27 mins
# 17:14:02   max GPU memory: 743.9 MiB
# 17:14:02   ------------------------------
# 17:14:02   average binary cross entropy: 0.0782569
# 17:14:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:02   Epoch 25 begin
# 17:14:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:03   Epoch 25 end
# 17:14:03   duration: 0.97 secs
# 17:14:03   speed: 5.17 batch / sec
# 17:14:03   ETA: 1.25 mins
# 17:14:03   max GPU memory: 739.6 MiB
# 17:14:03   ------------------------------
# 17:14:03   average binary cross entropy: 0.0850429
# 17:14:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:03   Epoch 26 begin
# 17:14:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:04   Epoch 26 end
# 17:14:04   duration: 1.04 secs
# 17:14:04   speed: 4.80 batch / sec
# 17:14:04   ETA: 1.24 mins
# 17:14:04   max GPU memory: 743.1 MiB
# 17:14:04   ------------------------------
# 17:14:04   average binary cross entropy: 0.0839196
# 17:14:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:04   Epoch 27 begin
# 17:14:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:05   Epoch 27 end
# 17:14:05   duration: 1.03 secs
# 17:14:05   speed: 4.88 batch / sec
# 17:14:05   ETA: 1.22 mins
# 17:14:05   max GPU memory: 741.4 MiB
# 17:14:05   ------------------------------
# 17:14:05   average binary cross entropy: 0.0764159
# 17:14:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:05   Epoch 28 begin
# 17:14:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:06   Epoch 28 end
# 17:14:06   duration: 1.03 secs
# 17:14:06   speed: 4.85 batch / sec
# 17:14:06   ETA: 1.21 mins
# 17:14:06   max GPU memory: 742.4 MiB
# 17:14:06   ------------------------------
# 17:14:06   average binary cross entropy: 0.0739725
# 17:14:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:06   Epoch 29 begin
# 17:14:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:07   Epoch 29 end
# 17:14:07   duration: 1.10 secs
# 17:14:07   speed: 4.55 batch / sec
# 17:14:07   ETA: 1.19 mins
# 17:14:07   max GPU memory: 744.5 MiB
# 17:14:07   ------------------------------
# 17:14:07   average binary cross entropy: 0.0689784
# 17:14:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:07   Epoch 30 begin
# 17:14:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:09   Epoch 30 end
# 17:14:09   duration: 1.49 secs
# 17:14:09   speed: 3.36 batch / sec
# 17:14:09   ETA: 1.19 mins
# 17:14:09   max GPU memory: 739.1 MiB
# 17:14:09   ------------------------------
# 17:14:09   average binary cross entropy: 0.0760138
# 17:14:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:09   Epoch 31 begin
# 17:14:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:10   Epoch 31 end
# 17:14:10   duration: 1.15 secs
# 17:14:10   speed: 4.33 batch / sec
# 17:14:10   ETA: 1.18 mins
# 17:14:10   max GPU memory: 739.4 MiB
# 17:14:10   ------------------------------
# 17:14:10   average binary cross entropy: 0.0759752
# 17:14:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:10   Epoch 32 begin
# 17:14:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:11   Epoch 32 end
# 17:14:11   duration: 1.26 secs
# 17:14:11   speed: 3.97 batch / sec
# 17:14:11   ETA: 1.17 mins
# 17:14:11   max GPU memory: 747.9 MiB
# 17:14:11   ------------------------------
# 17:14:11   average binary cross entropy: 0.0617537
# 17:14:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:11   Epoch 33 begin
# 17:14:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:13   Epoch 33 end
# 17:14:13   duration: 1.37 secs
# 17:14:13   speed: 3.65 batch / sec
# 17:14:13   ETA: 1.16 mins
# 17:14:13   max GPU memory: 742.6 MiB
# 17:14:13   ------------------------------
# 17:14:13   average binary cross entropy: 0.0605383
# 17:14:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:13   Epoch 34 begin
# 17:14:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:14   Epoch 34 end
# 17:14:14   duration: 1.15 secs
# 17:14:14   speed: 4.37 batch / sec
# 17:14:14   ETA: 1.15 mins
# 17:14:14   max GPU memory: 750.0 MiB
# 17:14:14   ------------------------------
# 17:14:14   average binary cross entropy: 0.0640028
# 17:14:14   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:14   Epoch 35 begin
# 17:14:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:15   Epoch 35 end
# 17:14:15   duration: 0.99 secs
# 17:14:15   speed: 5.03 batch / sec
# 17:14:15   ETA: 1.13 mins
# 17:14:15   max GPU memory: 741.0 MiB
# 17:14:15   ------------------------------
# 17:14:15   average binary cross entropy: 0.0629088
# 17:14:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:15   Epoch 36 begin
# 17:14:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:16   Epoch 36 end
# 17:14:16   duration: 0.99 secs
# 17:14:16   speed: 5.05 batch / sec
# 17:14:16   ETA: 1.11 mins
# 17:14:16   max GPU memory: 740.2 MiB
# 17:14:16   ------------------------------
# 17:14:16   average binary cross entropy: 0.0541293
# 17:14:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:16   Epoch 37 begin
# 17:14:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:17   Epoch 37 end
# 17:14:17   duration: 0.97 secs
# 17:14:17   speed: 5.14 batch / sec
# 17:14:17   ETA: 1.09 mins
# 17:14:17   max GPU memory: 748.4 MiB
# 17:14:17   ------------------------------
# 17:14:17   average binary cross entropy: 0.0553396
# 17:14:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:17   Epoch 38 begin
# 17:14:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:18   Epoch 38 end
# 17:14:18   duration: 1.03 secs
# 17:14:18   speed: 4.85 batch / sec
# 17:14:18   ETA: 1.07 mins
# 17:14:18   max GPU memory: 741.5 MiB
# 17:14:18   ------------------------------
# 17:14:18   average binary cross entropy: 0.0522116
# 17:14:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:18   Epoch 39 begin
# 17:14:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:19   Epoch 39 end
# 17:14:19   duration: 0.96 secs
# 17:14:19   speed: 5.22 batch / sec
# 17:14:19   ETA: 1.05 mins
# 17:14:19   max GPU memory: 738.9 MiB
# 17:14:19   ------------------------------
# 17:14:19   average binary cross entropy: 0.0452787
# 17:14:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:19   Epoch 40 begin
# 17:14:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:19   binary cross entropy: 0.0409182
# 17:14:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:20   Epoch 40 end
# 17:14:20   duration: 0.98 secs
# 17:14:20   speed: 5.10 batch / sec
# 17:14:20   ETA: 1.03 mins
# 17:14:20   max GPU memory: 739.4 MiB
# 17:14:20   ------------------------------
# 17:14:20   average binary cross entropy: 0.0422288
# 17:14:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:20   Epoch 41 begin
# 17:14:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:21   Epoch 41 end
# 17:14:21   duration: 1.00 secs
# 17:14:21   speed: 5.00 batch / sec
# 17:14:21   ETA: 1.01 mins
# 17:14:21   max GPU memory: 741.8 MiB
# 17:14:21   ------------------------------
# 17:14:21   average binary cross entropy: 0.0436603
# 17:14:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:21   Epoch 42 begin
# 17:14:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:22   Epoch 42 end
# 17:14:22   duration: 1.24 secs
# 17:14:22   speed: 4.03 batch / sec
# 17:14:22   ETA: 59.95 secs
# 17:14:22   max GPU memory: 738.9 MiB
# 17:14:22   ------------------------------
# 17:14:22   average binary cross entropy: 0.041668
# 17:14:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:22   Epoch 43 begin
# 17:14:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:23   Epoch 43 end
# 17:14:23   duration: 1.00 secs
# 17:14:23   speed: 4.99 batch / sec
# 17:14:23   ETA: 58.84 secs
# 17:14:23   max GPU memory: 740.5 MiB
# 17:14:23   ------------------------------
# 17:14:23   average binary cross entropy: 0.0396938
# 17:14:23   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:23   Epoch 44 begin
# 17:14:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:24   Epoch 44 end
# 17:14:24   duration: 1.04 secs
# 17:14:24   speed: 4.80 batch / sec
# 17:14:24   ETA: 57.78 secs
# 17:14:24   max GPU memory: 743.7 MiB
# 17:14:24   ------------------------------
# 17:14:24   average binary cross entropy: 0.0399236
# 17:14:24   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:24   Epoch 45 begin
# 17:14:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:25   Epoch 45 end
# 17:14:25   duration: 1.06 secs
# 17:14:25   speed: 4.71 batch / sec
# 17:14:25   ETA: 56.74 secs
# 17:14:25   max GPU memory: 742.7 MiB
# 17:14:25   ------------------------------
# 17:14:25   average binary cross entropy: 0.0379344
# 17:14:25   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:25   Epoch 46 begin
# 17:14:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:26   Epoch 46 end
# 17:14:26   duration: 1.02 secs
# 17:14:26   speed: 4.91 batch / sec
# 17:14:26   ETA: 55.65 secs
# 17:14:26   max GPU memory: 740.1 MiB
# 17:14:26   ------------------------------
# 17:14:26   average binary cross entropy: 0.0449569
# 17:14:26   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:26   Epoch 47 begin
# 17:14:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:27   Epoch 47 end
# 17:14:27   duration: 1.03 secs
# 17:14:27   speed: 4.88 batch / sec
# 17:14:27   ETA: 54.57 secs
# 17:14:27   max GPU memory: 742.1 MiB
# 17:14:27   ------------------------------
# 17:14:27   average binary cross entropy: 0.0399406
# 17:14:27   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:27   Epoch 48 begin
# 17:14:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:28   Epoch 48 end
# 17:14:28   duration: 0.97 secs
# 17:14:28   speed: 5.13 batch / sec
# 17:14:28   ETA: 53.45 secs
# 17:14:28   max GPU memory: 742.7 MiB
# 17:14:28   ------------------------------
# 17:14:28   average binary cross entropy: 0.0353944
# 17:14:28   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:28   Epoch 49 begin
# 17:14:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:29   Epoch 49 end
# 17:14:29   duration: 0.99 secs
# 17:14:29   speed: 5.07 batch / sec
# 17:14:29   ETA: 52.33 secs
# 17:14:29   max GPU memory: 741.6 MiB
# 17:14:29   ------------------------------
# 17:14:29   average binary cross entropy: 0.0361244
# 17:14:29   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:29   Epoch 50 begin
# 17:14:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:30   Epoch 50 end
# 17:14:30   duration: 0.97 secs
# 17:14:30   speed: 5.17 batch / sec
# 17:14:30   ETA: 51.21 secs
# 17:14:30   max GPU memory: 738.9 MiB
# 17:14:30   ------------------------------
# 17:14:30   average binary cross entropy: 0.0351973
# 17:14:30   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:30   Epoch 51 begin
# 17:14:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:31   Epoch 51 end
# 17:14:31   duration: 1.00 secs
# 17:14:31   speed: 5.00 batch / sec
# 17:14:31   ETA: 50.12 secs
# 17:14:31   max GPU memory: 738.9 MiB
# 17:14:31   ------------------------------
# 17:14:31   average binary cross entropy: 0.0344753
# 17:14:31   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:31   Epoch 52 begin
# 17:14:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:32   Epoch 52 end
# 17:14:32   duration: 0.98 secs
# 17:14:32   speed: 5.10 batch / sec
# 17:14:32   ETA: 49.02 secs
# 17:14:32   max GPU memory: 741.7 MiB
# 17:14:32   ------------------------------
# 17:14:32   average binary cross entropy: 0.032279
# 17:14:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:32   Epoch 53 begin
# 17:14:33   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:33   Epoch 53 end
# 17:14:33   duration: 1.08 secs
# 17:14:33   speed: 4.63 batch / sec
# 17:14:33   ETA: 48.01 secs
# 17:14:33   max GPU memory: 741.1 MiB
# 17:14:33   ------------------------------
# 17:14:33   average binary cross entropy: 0.02983
# 17:14:33   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:33   Epoch 54 begin
# 17:14:34   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:34   Epoch 54 end
# 17:14:34   duration: 1.09 secs
# 17:14:34   speed: 4.60 batch / sec
# 17:14:34   ETA: 47.00 secs
# 17:14:34   max GPU memory: 743.8 MiB
# 17:14:34   ------------------------------
# 17:14:34   average binary cross entropy: 0.0365946
# 17:14:34   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:34   Epoch 55 begin
# 17:14:35   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:35   Epoch 55 end
# 17:14:35   duration: 1.11 secs
# 17:14:35   speed: 4.49 batch / sec
# 17:14:35   ETA: 46.01 secs
# 17:14:35   max GPU memory: 743.5 MiB
# 17:14:35   ------------------------------
# 17:14:35   average binary cross entropy: 0.0362024
# 17:14:35   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:35   Epoch 56 begin
# 17:14:36   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:36   Epoch 56 end
# 17:14:36   duration: 1.06 secs
# 17:14:36   speed: 4.72 batch / sec
# 17:14:36   ETA: 44.98 secs
# 17:14:36   max GPU memory: 744.1 MiB
# 17:14:36   ------------------------------
# 17:14:36   average binary cross entropy: 0.0290598
# 17:14:36   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:36   Epoch 57 begin
# 17:14:37   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:37   Epoch 57 end
# 17:14:37   duration: 1.05 secs
# 17:14:37   speed: 4.74 batch / sec
# 17:14:37   ETA: 43.94 secs
# 17:14:37   max GPU memory: 742.9 MiB
# 17:14:37   ------------------------------
# 17:14:37   average binary cross entropy: 0.0336712
# 17:14:37   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:37   Epoch 58 begin
# 17:14:38   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:38   Epoch 58 end
# 17:14:38   duration: 0.99 secs
# 17:14:38   speed: 5.05 batch / sec
# 17:14:38   ETA: 42.85 secs
# 17:14:38   max GPU memory: 740.1 MiB
# 17:14:38   ------------------------------
# 17:14:38   average binary cross entropy: 0.0483107
# 17:14:38   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:38   Epoch 59 begin
# 17:14:39   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:39   Epoch 59 end
# 17:14:39   duration: 1.02 secs
# 17:14:39   speed: 4.88 batch / sec
# 17:14:39   ETA: 41.79 secs
# 17:14:39   max GPU memory: 738.9 MiB
# 17:14:39   ------------------------------
# 17:14:39   average binary cross entropy: 0.0389323
# 17:14:39   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:39   Epoch 60 begin
# 17:14:40   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:40   binary cross entropy: 0.0343322
# 17:14:41   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:41   Epoch 60 end
# 17:14:41   duration: 1.49 secs
# 17:14:41   speed: 3.36 batch / sec
# 17:14:41   ETA: 41.03 secs
# 17:14:41   max GPU memory: 740.5 MiB
# 17:14:41   ------------------------------
# 17:14:41   average binary cross entropy: 0.0359207
# 17:14:41   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:41   Epoch 61 begin
# 17:14:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:42   Epoch 61 end
# 17:14:42   duration: 1.23 secs
# 17:14:42   speed: 4.05 batch / sec
# 17:14:42   ETA: 40.09 secs
# 17:14:42   max GPU memory: 741.7 MiB
# 17:14:42   ------------------------------
# 17:14:42   average binary cross entropy: 0.0513542
# 17:14:42   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:42   Epoch 62 begin
# 17:14:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:43   Epoch 62 end
# 17:14:43   duration: 1.29 secs
# 17:14:43   speed: 3.87 batch / sec
# 17:14:43   ETA: 39.18 secs
# 17:14:43   max GPU memory: 747.2 MiB
# 17:14:43   ------------------------------
# 17:14:43   average binary cross entropy: 0.0505457
# 17:14:43   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:43   Epoch 63 begin
# 17:14:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:45   Epoch 63 end
# 17:14:45   duration: 1.19 secs
# 17:14:45   speed: 4.22 batch / sec
# 17:14:45   ETA: 38.19 secs
# 17:14:45   max GPU memory: 743.3 MiB
# 17:14:45   ------------------------------
# 17:14:45   average binary cross entropy: 0.0432788
# 17:14:45   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:45   Epoch 64 begin
# 17:14:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:46   Epoch 64 end
# 17:14:46   duration: 1.08 secs
# 17:14:46   speed: 4.63 batch / sec
# 17:14:46   ETA: 37.14 secs
# 17:14:46   max GPU memory: 742.5 MiB
# 17:14:46   ------------------------------
# 17:14:46   average binary cross entropy: 0.03742
# 17:14:46   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:46   Epoch 65 begin
# 17:14:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:47   Epoch 65 end
# 17:14:47   duration: 0.97 secs
# 17:14:47   speed: 5.17 batch / sec
# 17:14:47   ETA: 36.03 secs
# 17:14:47   max GPU memory: 743.3 MiB
# 17:14:47   ------------------------------
# 17:14:47   average binary cross entropy: 0.0351767
# 17:14:47   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:47   Epoch 66 begin
# 17:14:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:48   Epoch 66 end
# 17:14:48   duration: 0.97 secs
# 17:14:48   speed: 5.14 batch / sec
# 17:14:48   ETA: 34.93 secs
# 17:14:48   max GPU memory: 749.4 MiB
# 17:14:48   ------------------------------
# 17:14:48   average binary cross entropy: 0.0344005
# 17:14:48   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:48   Epoch 67 begin
# 17:14:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:49   Epoch 67 end
# 17:14:49   duration: 0.99 secs
# 17:14:49   speed: 5.06 batch / sec
# 17:14:49   ETA: 33.83 secs
# 17:14:49   max GPU memory: 738.9 MiB
# 17:14:49   ------------------------------
# 17:14:49   average binary cross entropy: 0.0296336
# 17:14:49   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:49   Epoch 68 begin
# 17:14:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:50   Epoch 68 end
# 17:14:50   duration: 0.98 secs
# 17:14:50   speed: 5.08 batch / sec
# 17:14:50   ETA: 32.74 secs
# 17:14:50   max GPU memory: 739.1 MiB
# 17:14:50   ------------------------------
# 17:14:50   average binary cross entropy: 0.0294978
# 17:14:50   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:50   Epoch 69 begin
# 17:14:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:51   Epoch 69 end
# 17:14:51   duration: 0.97 secs
# 17:14:51   speed: 5.16 batch / sec
# 17:14:51   ETA: 31.65 secs
# 17:14:51   max GPU memory: 742.1 MiB
# 17:14:51   ------------------------------
# 17:14:51   average binary cross entropy: 0.0356836
# 17:14:51   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:51   Epoch 70 begin
# 17:14:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:52   Epoch 70 end
# 17:14:52   duration: 1.00 secs
# 17:14:52   speed: 5.01 batch / sec
# 17:14:52   ETA: 30.57 secs
# 17:14:52   max GPU memory: 743.2 MiB
# 17:14:52   ------------------------------
# 17:14:52   average binary cross entropy: 0.0309816
# 17:14:52   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:52   Epoch 71 begin
# 17:14:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:53   Epoch 71 end
# 17:14:53   duration: 0.99 secs
# 17:14:53   speed: 5.07 batch / sec
# 17:14:53   ETA: 29.49 secs
# 17:14:53   max GPU memory: 740.8 MiB
# 17:14:53   ------------------------------
# 17:14:53   average binary cross entropy: 0.0235232
# 17:14:53   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:53   Epoch 72 begin
# 17:14:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:54   Epoch 72 end
# 17:14:54   duration: 0.96 secs
# 17:14:54   speed: 5.22 batch / sec
# 17:14:54   ETA: 28.40 secs
# 17:14:54   max GPU memory: 744.7 MiB
# 17:14:54   ------------------------------
# 17:14:54   average binary cross entropy: 0.0206811
# 17:14:54   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:54   Epoch 73 begin
# 17:14:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:55   Epoch 73 end
# 17:14:55   duration: 0.97 secs
# 17:14:55   speed: 5.16 batch / sec
# 17:14:55   ETA: 27.32 secs
# 17:14:55   max GPU memory: 740.0 MiB
# 17:14:55   ------------------------------
# 17:14:55   average binary cross entropy: 0.0201265
# 17:14:55   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:55   Epoch 74 begin
# 17:14:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:56   Epoch 74 end
# 17:14:56   duration: 0.99 secs
# 17:14:56   speed: 5.07 batch / sec
# 17:14:56   ETA: 26.25 secs
# 17:14:56   max GPU memory: 741.9 MiB
# 17:14:56   ------------------------------
# 17:14:56   average binary cross entropy: 0.0223477
# 17:14:56   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:56   Epoch 75 begin
# 17:14:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:57   Epoch 75 end
# 17:14:57   duration: 1.07 secs
# 17:14:57   speed: 4.69 batch / sec
# 17:14:57   ETA: 25.20 secs
# 17:14:57   max GPU memory: 743.0 MiB
# 17:14:57   ------------------------------
# 17:14:57   average binary cross entropy: 0.0188353
# 17:14:57   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:57   Epoch 76 begin
# 17:14:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:58   Epoch 76 end
# 17:14:58   duration: 1.00 secs
# 17:14:58   speed: 5.01 batch / sec
# 17:14:58   ETA: 24.14 secs
# 17:14:58   max GPU memory: 749.3 MiB
# 17:14:58   ------------------------------
# 17:14:58   average binary cross entropy: 0.0218033
# 17:14:58   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:58   Epoch 77 begin
# 17:14:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:59   Epoch 77 end
# 17:14:59   duration: 0.99 secs
# 17:14:59   speed: 5.07 batch / sec
# 17:14:59   ETA: 23.07 secs
# 17:14:59   max GPU memory: 740.4 MiB
# 17:14:59   ------------------------------
# 17:14:59   average binary cross entropy: 0.0216413
# 17:14:59   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:14:59   Epoch 78 begin
# 17:15:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:00   Epoch 78 end
# 17:15:00   duration: 1.00 secs
# 17:15:00   speed: 5.02 batch / sec
# 17:15:00   ETA: 22.01 secs
# 17:15:00   max GPU memory: 744.5 MiB
# 17:15:00   ------------------------------
# 17:15:00   average binary cross entropy: 0.0225137
# 17:15:00   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:00   Epoch 79 begin
# 17:15:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:01   Epoch 79 end
# 17:15:01   duration: 0.97 secs
# 17:15:01   speed: 5.18 batch / sec
# 17:15:01   ETA: 20.94 secs
# 17:15:01   max GPU memory: 742.5 MiB
# 17:15:01   ------------------------------
# 17:15:01   average binary cross entropy: 0.0178013
# 17:15:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:01   Epoch 80 begin
# 17:15:01   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:01   binary cross entropy: 0.0174164
# 17:15:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:02   Epoch 80 end
# 17:15:02   duration: 0.98 secs
# 17:15:02   speed: 5.11 batch / sec
# 17:15:02   ETA: 19.88 secs
# 17:15:02   max GPU memory: 738.9 MiB
# 17:15:02   ------------------------------
# 17:15:02   average binary cross entropy: 0.0212845
# 17:15:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:02   Epoch 81 begin
# 17:15:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:02   Epoch 81 end
# 17:15:02   duration: 0.95 secs
# 17:15:02   speed: 5.28 batch / sec
# 17:15:02   ETA: 18.81 secs
# 17:15:02   max GPU memory: 740.5 MiB
# 17:15:02   ------------------------------
# 17:15:02   average binary cross entropy: 0.0158081
# 17:15:02   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:02   Epoch 82 begin
# 17:15:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:03   Epoch 82 end
# 17:15:03   duration: 0.98 secs
# 17:15:03   speed: 5.12 batch / sec
# 17:15:03   ETA: 17.75 secs
# 17:15:03   max GPU memory: 739.4 MiB
# 17:15:03   ------------------------------
# 17:15:03   average binary cross entropy: 0.0170397
# 17:15:03   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:03   Epoch 83 begin
# 17:15:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:04   Epoch 83 end
# 17:15:04   duration: 0.99 secs
# 17:15:04   speed: 5.04 batch / sec
# 17:15:04   ETA: 16.70 secs
# 17:15:04   max GPU memory: 739.4 MiB
# 17:15:04   ------------------------------
# 17:15:04   average binary cross entropy: 0.0165847
# 17:15:04   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:04   Epoch 84 begin
# 17:15:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:05   Epoch 84 end
# 17:15:05   duration: 0.97 secs
# 17:15:05   speed: 5.13 batch / sec
# 17:15:05   ETA: 15.64 secs
# 17:15:05   max GPU memory: 741.7 MiB
# 17:15:05   ------------------------------
# 17:15:05   average binary cross entropy: 0.0184809
# 17:15:05   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:05   Epoch 85 begin
# 17:15:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:06   Epoch 85 end
# 17:15:06   duration: 0.97 secs
# 17:15:06   speed: 5.18 batch / sec
# 17:15:06   ETA: 14.59 secs
# 17:15:06   max GPU memory: 743.1 MiB
# 17:15:06   ------------------------------
# 17:15:06   average binary cross entropy: 0.0171118
# 17:15:06   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:06   Epoch 86 begin
# 17:15:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:07   Epoch 86 end
# 17:15:07   duration: 0.96 secs
# 17:15:07   speed: 5.18 batch / sec
# 17:15:07   ETA: 13.53 secs
# 17:15:07   max GPU memory: 741.8 MiB
# 17:15:07   ------------------------------
# 17:15:07   average binary cross entropy: 0.0225952
# 17:15:07   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:07   Epoch 87 begin
# 17:15:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:08   Epoch 87 end
# 17:15:08   duration: 0.95 secs
# 17:15:08   speed: 5.26 batch / sec
# 17:15:08   ETA: 12.48 secs
# 17:15:08   max GPU memory: 750.4 MiB
# 17:15:08   ------------------------------
# 17:15:08   average binary cross entropy: 0.0203083
# 17:15:08   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:08   Epoch 88 begin
# 17:15:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:09   Epoch 88 end
# 17:15:09   duration: 1.00 secs
# 17:15:09   speed: 5.02 batch / sec
# 17:15:09   ETA: 11.43 secs
# 17:15:09   max GPU memory: 743.5 MiB
# 17:15:09   ------------------------------
# 17:15:09   average binary cross entropy: 0.0173137
# 17:15:09   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:09   Epoch 89 begin
# 17:15:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:10   Epoch 89 end
# 17:15:10   duration: 1.04 secs
# 17:15:10   speed: 4.82 batch / sec
# 17:15:10   ETA: 10.39 secs
# 17:15:10   max GPU memory: 740.5 MiB
# 17:15:10   ------------------------------
# 17:15:10   average binary cross entropy: 0.0158128
# 17:15:10   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:10   Epoch 90 begin
# 17:15:11   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:11   Epoch 90 end
# 17:15:11   duration: 1.18 secs
# 17:15:11   speed: 4.25 batch / sec
# 17:15:11   ETA: 9.37 secs
# 17:15:12   max GPU memory: 738.8 MiB
# 17:15:12   ------------------------------
# 17:15:12   average binary cross entropy: 0.017423
# 17:15:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:12   Epoch 91 begin
# 17:15:12   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:12   Epoch 91 end
# 17:15:12   duration: 1.00 secs
# 17:15:12   speed: 5.01 batch / sec
# 17:15:12   ETA: 8.32 secs
# 17:15:12   max GPU memory: 743.0 MiB
# 17:15:12   ------------------------------
# 17:15:13   average binary cross entropy: 0.0182665
# 17:15:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:13   Epoch 92 begin
# 17:15:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:13   Epoch 92 end
# 17:15:13   duration: 0.99 secs
# 17:15:13   speed: 5.05 batch / sec
# 17:15:13   ETA: 7.28 secs
# 17:15:13   max GPU memory: 740.7 MiB
# 17:15:13   ------------------------------
# 17:15:13   average binary cross entropy: 0.021805
# 17:15:13   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:13   Epoch 93 begin
# 17:15:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:15   Epoch 93 end
# 17:15:15   duration: 1.02 secs
# 17:15:15   speed: 4.90 batch / sec
# 17:15:15   ETA: 6.24 secs
# 17:15:15   max GPU memory: 739.8 MiB
# 17:15:15   ------------------------------
# 17:15:15   average binary cross entropy: 0.0181396
# 17:15:15   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:15   Epoch 94 begin
# 17:15:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:16   Epoch 94 end
# 17:15:16   duration: 1.02 secs
# 17:15:16   speed: 4.89 batch / sec
# 17:15:16   ETA: 5.20 secs
# 17:15:16   max GPU memory: 738.9 MiB
# 17:15:16   ------------------------------
# 17:15:16   average binary cross entropy: 0.0136788
# 17:15:16   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:16   Epoch 95 begin
# 17:15:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:17   Epoch 95 end
# 17:15:17   duration: 0.98 secs
# 17:15:17   speed: 5.09 batch / sec
# 17:15:17   ETA: 4.16 secs
# 17:15:17   max GPU memory: 739.4 MiB
# 17:15:17   ------------------------------
# 17:15:17   average binary cross entropy: 0.0108809
# 17:15:17   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:17   Epoch 96 begin
# 17:15:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:18   Epoch 96 end
# 17:15:18   duration: 1.04 secs
# 17:15:18   speed: 4.79 batch / sec
# 17:15:18   ETA: 3.12 secs
# 17:15:18   max GPU memory: 740.7 MiB
# 17:15:18   ------------------------------
# 17:15:18   average binary cross entropy: 0.0115493
# 17:15:18   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:18   Epoch 97 begin
# 17:15:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:19   Epoch 97 end
# 17:15:19   duration: 1.04 secs
# 17:15:19   speed: 4.79 batch / sec
# 17:15:19   ETA: 2.08 secs
# 17:15:19   max GPU memory: 738.9 MiB
# 17:15:19   ------------------------------
# 17:15:19   average binary cross entropy: 0.00985576
# 17:15:19   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:19   Epoch 98 begin
# 17:15:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:20   Epoch 98 end
# 17:15:20   duration: 1.00 secs
# 17:15:20   speed: 5.00 batch / sec
# 17:15:20   ETA: 1.04 secs
# 17:15:20   max GPU memory: 740.7 MiB
# 17:15:20   ------------------------------
# 17:15:20   average binary cross entropy: 0.00897908
# 17:15:20   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:20   Epoch 99 begin
# 17:15:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:21   Epoch 99 end
# 17:15:21   duration: 0.98 secs
# 17:15:21   speed: 5.08 batch / sec
# 17:15:21   ETA: 0.00 secs
# 17:15:21   max GPU memory: 741.2 MiB
# 17:15:21   ------------------------------
# 17:15:21   average binary cross entropy: 0.00950596

# %% [markdown]
# Validate model

# %%
solver.evaluate("train")
solver.evaluate("valid")
solver.evaluate("test")
# Out:
# 17:15:21   Evaluate on train
# 17:15:21   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:21   auprc [target1]: 0.99998
# 17:15:21   auprc [target2]: 0.999981
# 17:15:21   auroc [target1]: 0.999988
# 17:15:21   auroc [target2]: 0.999965
# 17:15:21   Evaluate on valid
# 17:15:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:22   auprc [target1]: 0.994305
# 17:15:22   auprc [target2]: 0.996335
# 17:15:22   auroc [target1]: 0.995869
# 17:15:22   auroc [target2]: 0.994529
# 17:15:22   Evaluate on test
# 17:15:22   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:15:22   auprc [target1]: 0.995304
# 17:15:22   auprc [target2]: 0.998461
# 17:15:22   auroc [target1]: 0.997508
# 17:15:22   auroc [target2]: 0.997179
# {'auprc [target1]': tensor(0.9953, device='cuda:0'),
#  'auprc [target2]': tensor(0.9985, device='cuda:0'),
#  'auroc [target1]': tensor(0.9975, device='cuda:0'),
#  'auroc [target2]': tensor(0.9972, device='cuda:0')}

# %% [markdown]
# save and load

# %%
import json

with open("../models/" + DATASET_NAME + ".json", "w") as fout:
    json.dump(solver.config_dict(), fout)
solver.save("../models/" + DATASET_NAME + ".pth")
# Out:
# 16:56:00   Save checkpoint to ../models/chembl29_dt_cpds_Q9Y5N1_P31645.pth

# %%
with open("../models/" + DATASET_NAME + ".json", "r") as fin:
    solver = core.Configurable.load_config_dict(json.load(fin))
solver.load("../models/" + DATASET_NAME + ".pth")
# Out:
# Loading ../data/chembl29_predicting_target_P14416_P42336.csv: 100%|██████████| 7634/7634 [00:00<00:00, 57331.02it/s]
# Constructing molecules from SMILES: 100%|██████████| 7633/7633 [00:31<00:00, 239.89it/s]
# Loading ../data/chembl29_predicting_target_P14416_P42336.csv: 100%|██████████| 7634/7634 [00:00<00:00, 69109.47it/s]
# Constructing molecules from SMILES: 100%|██████████| 7633/7633 [00:31<00:00, 240.03it/s]
# Loading ../data/chembl29_predicting_target_P14416_P42336.csv: 100%|██████████| 7634/7634 [00:00<00:00, 60267.12it/s]
# Constructing molecules from SMILES: 100%|██████████| 7633/7633 [00:45<00:00, 168.85it/s]
# 17:00:31   Preprocess training set
# 17:00:31   Load checkpoint from ../models/chembl29_predicting_target_P14416_P42336.pth

# %% [markdown]
# evalutad loaded model

# %%
solver.evaluate("train")

solver.evaluate("valid")

solver.evaluate("test")
# Out:
# 17:00:31   Evaluate on train
# 17:00:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:00:32   auprc [label]: 1
# 17:00:32   auroc [label]: 1
# 17:00:32   Evaluate on valid
# 17:00:32   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:00:32   auprc [label]: 0.999807
# 17:00:32   auroc [label]: 0.999833
# 17:00:32   Evaluate on test
# 17:00:33   >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# 17:00:33   auprc [label]: 0.999902
# 17:00:33   auroc [label]: 0.999923
# {'auprc [label]': tensor(0.9999, device='cuda:0'),
#  'auroc [label]': tensor(0.9999, device='cuda:0')}
